# %%
import time, datetime
import requests 
import pickle as pkl 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm, trange
import json

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn import metrics
import time


import warnings
warnings.filterwarnings('ignore')


from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support

# %%
from sklearn.model_selection import train_test_split

# %%
label_data = pd.read_pickle(r'all_metrics_data.pkl')
label_data.head()

X_train, X_test, Y_train, Y_test = train_test_split(label_data.drop(['label', 'time', 'txn_fail_num'],axis=1)\
                                                    , label_data.label, test_size=0.2, random_state=22)

# %%
from scipy import stats
import pprint

labels_to_correlate = label_data.drop(['label', 'time'], axis=1)

correlation_txn_falure = {}
for label in labels_to_correlate.columns:
    r,p = stats.pearsonr(labels_to_correlate[label], label_data.label)
    correlation_txn_falure[label] = (r,p)

# %%
correlation_txn_falure
# Out:
# {'txn_fail_num': (0.9905346158487722, 0.0),
#  'CPU Busy': (0.9304468374956792, 1.1273566604919168e-209),
#  'Sys Load (5m avg)': (0.8171667727278384, 5.691490767501555e-116),
#  'Sys Load (15m avg)': (0.5900622534284715, 3.578910784733229e-46),
#  'RAM Used': (0.35923180451467734, 5.251564305550307e-16),
#  'SWAP Used': (nan, nan),
#  'CPU Cores': (nan, nan),
#  'Uptime': (0.09493015506357566, 0.03801143821662601),
#  'RAM Total': (nan, nan),
#  'SWAP Total': (nan, nan),
#  'Busy System': (-0.6193715104007513, 5.666077769301473e-52),
#  'Busy User': (-0.8275648233758747, 1.938070763742404e-121),
#  'Busy Iowait': (0.9363868101569319, 1.3793564415818555e-218),
#  'Busy IRQs': (-0.3526593921134466, 1.913575059764708e-15),
#  'Busy Other': (-0.012069799805956436, 0.792393916319892),
#  'Idle': (-0.9304468374956792, 1.1273566604919168e-209),
#  'RAM Cache + Buffer': (0.33666722366826135, 3.9309787621271633e-14),
#  'RAM Free': (-0.3378256940993449, 3.1763618919601045e-14),
#  'recv eth0': (-0.040371017162821966, 0.37848660343253104),
#  'trans eth0 ': (0.6972258238186407, 7.996387315292145e-71),
#  '/etc/hostname': (0.20764108571731502, 4.69887719618891e-06),
#  'System - Processes executing in kernel mode': (-0.6193715104007513,
#   5.666077769301473e-52),
#  'User - Normal processes executing in user mode': (-0.8275648233758747,
#   1.938070763742404e-121),
#  'Nice - Niced processes executing in user mode': (-0.012069799805956436,
#   0.792393916319892),
#  'Iowait - Waiting for I/O to complete': (0.9363868101569319,
#   1.3793564415818555e-218),
#  'Irq - Servicing interrupts': (nan, nan),
#  'Softirq - Servicing softirqs': (-0.3526593921134466, 1.913575059764708e-15),
#  'Steal - Time spent in other operating systems when running in a virtualized environment': (nan,
#   nan),
#  'Apps - Memory used by user-space applications': (0.3154120241784295,
#   1.6789487039443387e-12),
#  'PageTables - Memory used to map between virtual and physical memory addresses': (0.7173601125527079,
#   9.928562348304738e-77),
#  'SwapCache - Memory that keeps track of pages that have been fetched from swap but not yet been modified': (nan,
#   nan),
#  'Slab - Memory used by the kernel to cache data structures for its own use (caches like inode, dentry, etc)': (0.36733146851018683,
#   1.0235715779610604e-16),
#  'Cache - Parked file data (file content) cache': (0.3365824129675147,
#   3.992661222903184e-14),
#  'Buffers - Block device (e.g. harddisk) cache': (0.2011955616767676,
#   9.307252969430946e-06),
#  'Hardware Corrupted - Amount of RAM that the kernel identified as corrupted / not working': (nan,
#   nan),
#  'Network Traffic': (0.09518699068003622, 0.037491590870002756),
#  'sda - Reads completed': (-0.08683307543388434, 0.057819519512638085),
#  'sda - Writes completed': (-0.9046533469490496, 1.8928550775886342e-178),
#  'sda - Successfully read bytes': (-0.06358249880351026, 0.16517280293492256),
#  'sda - Successfully written bytes': (0.9422443195341541,
#   2.9139942822075087e-228),
#  'sda': (0.9397445720455104, 5.153116886341863e-224),
#  'Inactive - Memory which has been less recently used.  It is more eligible to be reclaimed for other purposes': (0.32849151973089274,
#   1.7251238090727985e-13),
#  'Active - Memory that has been used more recently and usually not reclaimed unless absolutely necessary': (0.2707836612701485,
#   1.771507488735913e-09),
#  'Committed_AS - Amount of memory presently allocated on the system': (0.7969425547212343,
#   2.8405444692797657e-106),
#  'CommitLimit - Amount of  memory currently available to be allocated on the system': (nan,
#   nan),
#  'Inactive_file - File-backed memory on inactive LRU list': (0.3282817151373223,
#   1.7908203623398586e-13),
#  'Inactive_anon - Anonymous and swap cache on inactive LRU list, including tmpfs (shmem)': (0.9832157012988345,
#   0.0),
#  'Active_file - File-backed memory on active LRU list': (0.4883796980165599,
#   5.090208674689191e-30),
#  'Active_anon - Anonymous and swap cache on active least-recently-used (LRU) list, including tmpfs': (0.030902811607259786,
#   0.5002943191651575),
#  'Writeback - Memory which is actively being written back to disk': (0.943903371670118,
#   3.4625067194226776e-231),
#  'WritebackTmp - Memory used by FUSE for temporary writeback buffers': (nan,
#   nan),
#  'Dirty - Memory which is waiting to get written back to the disk': (0.7571706579862854,
#   4.471325130557586e-90),
#  'Mapped - Used memory in mapped pages files which have been mmaped, such as libraries': (0.510040279859734,
#   5.130949661958207e-33),
#  'Shmem - Used shared memory (shared between several processes, thus including RAM disks)': (0.9832155459394534,
#   0.0),
#  'ShmemHugePages - Memory used by shared memory (shmem) and tmpfs allocated  with huge pages': (nan,
#   nan),
#  'ShmemPmdMapped - Ammount of shared (shmem/tmpfs) memory backed by huge pages': (nan,
#   nan),
#  'SUnreclaim - Part of Slab, that cannot be reclaimed on memory pressure': (0.8174554993154599,
#   4.056382778957807e-116),
#  'SReclaimable - Part of Slab, that might be reclaimed, such as caches': (0.3626386015298366,
#   2.6548591718098006e-16),
#  'VmallocChunk - Largest contigious block of vmalloc area which is free': (nan,
#   nan),
#  'VmallocTotal - Total size of vmalloc memory area': (nan, nan),
#  'VmallocUsed - Amount of vmalloc area which is used': (0.7003726135923892,
#   1.0292842040637823e-71),
#  'Bounce - Memory used for block device bounce buffers': (nan, nan),
#  'AnonHugePages - Memory in anonymous huge pages': (-0.08600515649218161,
#   0.06025700322186095),
#  'AnonPages - Memory in user pages not backed by files': (0.30957308559490115,
#   4.475612043531437e-12),
#  'KernelStack - Kernel memory stack. This is not reclaimable': (0.7009903377498562,
#   6.860938050492245e-72),
#  'PerCPU - Per CPU memory allocated dynamically by loadable modules': (nan,
#   nan),
#  'HugePages_Free - Huge pages in the pool that are not yet allocated': (nan,
#   nan),
#  'HugePages_Rsvd - Huge pages for which a commitment to allocate from the pool has been made, but no allocation has yet been made': (nan,
#   nan),
#  'HugePages_Surp - Huge pages in the pool above the value in /proc/sys/vm/nr_hugepages': (nan,
#   nan),
#  'HugePages - Total size of the pool of huge pages': (nan, nan),
#  'Hugepagesize - Huge Page size': (nan, nan),
#  'DirectMap1G - Amount of pages mapped as this size': (nan, nan),
#  'DirectMap2M - Amount of pages mapped as this size': (nan, nan),
#  'DirectMap4K - Amount of pages mapped as this size': (nan, nan),
#  "Unevictable - Amount of unevictable memory that can't be swapped out for a variety of reasons": (0.9833712936736027,
#   0.0),
#  'MLocked - Size of pages locked to memory using the mlock() system call': (0.9833712936736027,
#   0.0),
#  'NFS Unstable - Memory in NFS pages sent to the server, but not yet commited to the storage': (nan,
#   nan),
#  'Pagesin - Page in operations': (-0.06356524739234003, 0.1652877506482822),
#  'Pagesout - Page out operations': (0.9443436898771738,
#   5.598609809796926e-232),
#  'Pswpin - Pages swapped in': (nan, nan),
#  'Pswpout - Pages swapped out': (nan, nan),
#  'Pgfault - Page major and minor fault operations': (-0.06180169116468998,
#   0.17735770267610615),
#  'Pgmajfault - Major page fault operations': (-0.037999038121472886,
#   0.40715803735765044),
#  'Pgminfault - Minor page fault operations': (-0.061803511079824555,
#   0.17734491843893768),
#  'oom killer invocations ': (nan, nan),
#  'Estimated error in seconds': (nan, nan),
#  'Time offset in between local system and reference clock': (0.3514712828659462,
#   2.4097424387254808e-15),
#  'Maximum error in seconds': (0.054658462379478814, 0.23295847914642523),
#  'Phase-locked loop time adjust': (nan, nan),
#  'Is clock synchronized to a reliable server (1 = yes, 0 = no)': (nan, nan),
#  'Local clock frequency adjustment': (0.3540705487774654,
#   1.4533604624079728e-15),
#  'Seconds between clock ticks': (nan, nan),
#  'International Atomic Time (TAI) offset': (nan, nan),
#  'Processes blocked waiting for I/O to complete': (0.7655005810177739,
#   3.3621471996843406e-93),
#  'Processes in runnable state': (0.013204750696875864, 0.7733812362923775),
#  'Processes forks second': (-0.09905853466244376, 0.03035740722457558),
#  'Processes virtual memory size in bytes': (nan, nan),
#  'Maximum amount of virtual memory available in bytes': (nan, nan),
#  'CPU 0 - seconds spent running a process': (-0.7467013448464151,
#   2.5217947341469957e-86),
#  'CPU 0 - seconds spent by processing waiting for this CPU': (-0.7836582779781469,
#   1.7529659937824583e-100),
#  'Context switches': (-0.7459245554406834, 4.706261073755773e-86),
#  'Interrupts': (-0.7448572481871841, 1.1050350410441872e-85),
#  'Load 1m': (0.8044810496047203, 9.369151164752849e-110),
#  'Load 5m': (0.8171667727278384, 5.691490767501555e-116),
#  'Load 15m': (0.5900622534284714, 3.578910784733229e-46),
#  'CPU 0': (-0.750274196392316, 1.3884463326795473e-87),
#  'Entropy available to random number generators': (0.29104048592858806,
#   8.734240511053416e-11),
#  'Time spent': (0.5516616759449763, 2.0467867839115105e-39),
#  'Maximum open file descriptors': (nan, nan),
#  'Open file descriptors': (nan, nan),
#  'Current 0 in {{ type }}': (nan, nan),
#  'Max 0 in {{ type }}': (nan, nan),
#  'sda - Read bytes': (-0.06358249880351026, 0.16517280293492256),
#  'sda - Written bytes': (0.9422443195341541, 2.9139942822075087e-228),
#  'sda - r_await': (0.528462954697648, 9.70543068527239e-36),
#  'sda - w_await': (0.9363267441526782, 1.714155879729673e-218),
#  'sda - Read merged': (-0.03321810212143288, 0.46872638492922514),
#  'sda - Write merged': (-0.9231256729571828, 1.0168816386102796e-199),
#  'sda - IO': (-0.9121963810051363, 1.4565494297752277e-186),
#  'sda - discard': (0.8792182459910173, 2.195032604987319e-155),
#  'sda - IO now': (nan, nan),
#  'sda - Discards completed': (0.17994411675182867, 7.615316766581e-05),
#  'sda - Discards merged': (nan, nan),
#  '/etc/hostname - Available': (-0.20764108571731502, 4.69887719618891e-06),
#  '/etc/hostname - Free': (-0.20764108571731502, 4.69887719618891e-06),
#  '/etc/hostname - Size': (nan, nan),
#  '/etc/hostname - Free file nodes': (-0.20950475875274066,
#   3.840704567951996e-06),
#  'Max open files': (nan, nan),
#  'Open files': (0.3547108450989998, 1.2822321565374175e-15),
#  '/etc/hostname - File nodes total': (nan, nan),
#  '/etc/hostname - ReadOnly': (nan, nan),
#  '/etc/hostname - Device error': (nan, nan),
#  'eth0 - Receive': (0.0905947000674362, 0.04775102862312331),
#  'eth0 - Transmit': (0.04842985273363727, 0.2906576673079873),
#  'eth0 - Receive errors': (nan, nan),
#  'eth0 - Rransmit errors': (nan, nan),
#  'eth0 - Receive drop': (nan, nan),
#  'eth0 - Transmit drop': (nan, nan),
#  'eth0 - Receive compressed': (nan, nan),
#  'eth0 - Transmit compressed': (nan, nan),
#  'eth0 - Receive multicast': (nan, nan),
#  'eth0 - Receive fifo': (nan, nan),
#  'eth0 - Transmit fifo': (nan, nan),
#  'eth0 - Receive frame': (nan, nan),
#  'eth0 - Statistic transmit_carrier': (nan, nan),
#  'eth0 - Transmit colls': (nan, nan),
#  'NF conntrack entries': (nan, nan),
#  'NF conntrack limit': (nan, nan),
#  'eth0 - ARP entries': (nan, nan),
#  'eth0 - Bytes': (nan, nan),
#  'eth0 - Speed': (nan, nan),
#  'eth0 -   Interface transmit queue length': (nan, nan),
#  'CPU 0 - Processed': (-0.6900491534886295, 7.776233916638143e-69),
#  'CPU 0 - Dropped': (nan, nan),
#  'CPU 0 - Squeezed': (-0.1362727007188349, 0.0028311805863035677),
#  'eth0 - Physical link state': (nan, nan),
#  'TCP_alloc - Allocated sockets': (-0.05135935840743178, 0.2624239794090014),
#  'TCP_inuse - Tcp sockets currently in use': (nan, nan),
#  'TCP_mem - Used memory for tcp': (-0.2000957901719539, 1.043591535019136e-05),
#  'TCP_orphan - Orphan sockets': (-0.025966639622130028, 0.5711740752375359),
#  'TCP_tw - Sockets wating close': (nan, nan),
#  'UDPLITE_inuse - Udplite sockets currently in use': (nan, nan),
#  'UDP_inuse - Udp sockets currently in use': (nan, nan),
#  'UDP_mem - Used memory for udp': (0.014657625284777792, 0.749240575055259),
#  'Sockets_used - Sockets currently in use': (nan, nan),
#  'mem_bytes - TCP sockets in that state': (-0.2000957901719539,
#   1.043591535019136e-05),
#  'mem_bytes - UDP sockets in that state': (0.014657625284777792,
#   0.749240575055259),
#  'FRAG_inuse - Frag sockets currently in use': (nan, nan),
#  'FRAG_memory - Used memory for frag': (nan, nan),
#  'RAW_inuse - Raw sockets currently in use': (nan, nan),
#  'InOctets - Received octets': (-0.1259025923535622, 0.005844075039727734),
#  'OutOctets - Sent octets': (0.696619473802341, 1.1833838128994208e-70),
#  'Forwarding - IP forwarding': (nan, nan),
#  'InMsgs -  Messages which the entity received. Note that this counter includes all those counted by icmpInErrors': (nan,
#   nan),
#  'OutMsgs - Messages which this entity attempted to send. Note that this counter includes all those counted by icmpOutErrors': (nan,
#   nan),
#  'InErrors - Messages which the entity received but determined as having ICMP-specific errors (bad ICMP checksums, bad length, etc.)': (nan,
#   nan),
#  'InDatagrams - Datagrams received': (nan, nan),
#  'OutDatagrams - Datagrams sent': (nan, nan),
#  'InErrors - UDP Datagrams that could not be delivered to an application': (nan,
#   nan),
#  'NoPorts - UDP Datagrams received on a port with no listener': (nan, nan),
#  'InErrors Lite - UDPLite Datagrams that could not be delivered to an application': (nan,
#   nan),
#  'RcvbufErrors - UDP buffer errors received': (nan, nan),
#  'SndbufErrors - UDP buffer errors send': (nan, nan),
#  'InSegs - Segments received, including those received in error. This count includes segments received on currently established connections': (0.34969935493601173,
#   3.392435058198636e-15),
#  'OutSegs - Segments sent, including those on current connections but excluding those containing only retransmitted octets': (-0.045822700803918454,
#   0.3174394591866302),
#  'ListenOverflows - Times the listen queue of a socket overflowed': (nan, nan),
#  'ListenDrops - SYNs to LISTEN sockets ignored': (nan, nan),
#  'TCPSynRetrans - SYN-SYN/ACK retransmits to break down retransmissions in SYN, fast/timeout retransmits': (nan,
#   nan),
#  'RetransSegs - Segments retransmitted - that is, the number of TCP segments transmitted containing one or more previously transmitted octets': (0.34947159377696435,
#   3.5443521068647103e-15),
#  'InErrs - Segments received in error (e.g., bad TCP checksums)': (nan, nan),
#  'CurrEstab - TCP connections for which the current state is either ESTABLISHED or CLOSE- WAIT': (nan,
#   nan),
#  'SyncookiesFailed - Invalid SYN cookies received': (nan, nan),
#  'SyncookiesRecv - SYN cookies received': (nan, nan),
#  'SyncookiesSent - SYN cookies sent': (nan, nan),
#  'ActiveOpens - TCP connections that have made a direct transition to the SYN-SENT state from the CLOSED state': (nan,
#   nan),
#  'PassiveOpens - TCP connections that have made a direct transition to the SYN-RCVD state from the LISTEN state': (nan,
#   nan),
#  'arp - Scrape duration': (-0.05320403090412472, 0.24564684489890853),
#  'arp - Scrape success': (nan, nan),
#  '{{collector}} - Scrape textfile error (1 = true)': (nan, nan)}

# %%
import seaborn as sns

txn_falure_correlation = pd.DataFrame.from_dict(correlation_txn_falure, orient='index').rename(columns={0:'r', 1:'p-value'}).sort_values('r', ascending=False)

plt.figure(figsize=(20,20))
sns.heatmap(txn_falure_correlation, cmap='GnBu', square=True, annot=False, linewidths=.5)

# %%
from scipy import stats
import pprint

correlation_txn_falure_bool = {}
for label in labels_to_correlate.columns:
    r,p = stats.pointbiserialr(labels_to_correlate[label], label_data.label)
    correlation_txn_falure_bool[label] = (r,p)
pointbiserialr = pd.DataFrame.from_dict(correlation_txn_falure_bool, orient='index').rename(columns={0:'r', 1:'p-value'}).sort_values('r', ascending=False)

print(pointbiserialr.head())
plt.figure(figsize=(22,22))
sns.heatmap(pointbiserialr, cmap='GnBu', square=True, annot=False, linewidths=.5)
# Out:
#                                                            r  p-value
# txn_fail_num                                        0.990535      0.0
# Unevictable - Amount of unevictable memory that...  0.983371      0.0
# MLocked - Size of pages locked to memory using ...  0.983371      0.0
# Inactive_anon - Anonymous and swap cache on ina...  0.983216      0.0
# Shmem - Used shared memory (shared between seve...  0.983216      0.0

# %%
correlations = label_data.corr().dropna(axis=1, how='all').T.dropna(axis=1, how='all').T
# heatmap

matrix = np.triu(correlations)

plt.figure(figsize=(11,9))
sns.heatmap(correlations, cmap='GnBu', square=True, annot=False, linewidths=.5, mask=matrix)
#plt.savefig('xx.png')

# %%
# drop unkonwn metrics looks like those are duplicates
df_index = list(txn_falure_correlation.index)

# drop Nan
txn_falure_correlation = txn_falure_correlation.dropna(axis='rows')
txn_falure_correlation
# Out:
#                                                            r        p-value
# txn_fail_num                                        0.990535   0.000000e+00
# Unevictable - Amount of unevictable memory that...  0.983371   0.000000e+00
# MLocked - Size of pages locked to memory using ...  0.983371   0.000000e+00
# Inactive_anon - Anonymous and swap cache on ina...  0.983216   0.000000e+00
# Shmem - Used shared memory (shared between seve...  0.983216   0.000000e+00
# ...                                                      ...            ...
# Busy User                                          -0.827565  1.938071e-121
# sda - Writes completed                             -0.904653  1.892855e-178
# sda - IO                                           -0.912196  1.456549e-186
# sda - Write merged                                 -0.923126  1.016882e-199
# Idle                                               -0.930447  1.127357e-209
#
# [102 rows x 2 columns]

# %%
selected_features = txn_falure_correlation[np.abs(txn_falure_correlation.r) >0.5]
selected_features = selected_features[selected_features['p-value'] < 0.05]
selected_features = selected_features.drop('txn_fail_num')
selected_features_names = selected_features.index

# %%
from sklearn.preprocessing import MinMaxScaler
normalized_label_data = label_data.copy()

for i in normalized_label_data.drop(['time'], axis=1).columns:  
    normalized_label_data[i]/=normalized_label_data[i].max()

# Old method use all selected features separately
for feature in selected_features_names:
    fig, ax =plt.subplots(figsize=(18,7))
    
    plt.subplot(1,2,1)
    plt.plot(normalized_label_data['time'], normalized_label_data[feature], label=feature)
    plt.plot(normalized_label_data['time'],normalized_label_data['label'],label='caliper_txn_falue')
    
    plt.subplot(1,2,2)
    plt.suptitle("Normalized caliper txn falue and "+feature)
    plt.scatter(label_data['label'], label_data[feature])
    plt.xlabel('caliper_txn_falure')
    plt.ylabel(feature)
    plt.show()

# %%
selected_features = txn_falure_correlation[np.abs(txn_falure_correlation.r) >0.5]
selected_features = selected_features[selected_features['p-value'] < 0.05]
selected_features_names = selected_features.index
selected_features_names = selected_features_names.drop('txn_fail_num')

# %% [markdown]
# # PCA

# %%
import numpy as np
from sklearn.decomposition import PCA

all_metrics = label_data.drop(['time', 'label', "txn_fail_num"], axis = 1).columns

# How to justify components?
pca = PCA(n_components=5)
pca_df = pca.fit_transform(label_data.drop(['time', 'label', 'txn_fail_num'], axis=1))
pca.fit(label_data.drop(['time', 'label'], axis=1))

print(pca.explained_variance_ratio_)
print(pca.singular_values_)
X_pca_train, X_pca_test, Y_pca_train, Y_pca_test = train_test_split(pca_df, label_data.label, test_size=0.2, random_state=22)
# Out:
# [9.85962944e-01 1.34492632e-02 3.25842951e-04 2.00910845e-04
#  4.51572188e-05]
# [2.65104904e+11 3.09625494e+10 4.81938510e+09 3.78433135e+09
#  1.79411823e+09]

# %%
#New method combine all selected features

from sklearn.ensemble import IsolationForest
#clf=IsolationForest(n_estimators=100, max_samples='auto', contamination=float(.12), \
#                        max_features=1.0, bootstrap=False, n_jobs=-1, random_state=42, verbose=0)
clf=IsolationForest(random_state=0)

def dbscan_(df):
    clf.fit(df)
    pred = clf.predict(df)
    test_df=pd.DataFrame()
#     Find decision function to find the score and classify anomalies
    test_df['score']=clf.decision_function(df)
    # test_df['actuals']=metrics_df[list(all_metrics)]
    test_df['anomaly']=pred
    # Get the indexes of outliers in order to compare the metrics     with use case anomalies if required
    outliers=test_df.loc[test_df['anomaly']==-1]
    outlier_index=list(outliers.index)

    # test_df=classify_anomalies(test_df,metrics_df.columns[i])
    # plot_anomaly(test_df,metrics_df.columns[i])

    for i,j in enumerate(pred):
        if j == 1:
            pred[i] = 0
        else: 
            pred[i] = 1
    return pred

def result(y_real, y_pred, method):
    accuracy = accuracy_score(y_real,y_pred)
    print(method)
    print('Accuracy: ', accuracy)
    # precision
    precision = precision_score(y_real, y_pred, average='macro')
    print('Precision: ', precision)
    # recall
    recall = metrics.recall_score(y_real, y_pred, average='macro')
    print('Recall: ', recall)
    f1_score = metrics.f1_score(y_real, y_pred, average='macro') 
    print('F1 score: ', f1_score)
    
    # AUC curve
    fpr, tpr, threshold = metrics.roc_curve(y_real, y_pred)
    roc_auc = metrics.auc(fpr, tpr)
    plt.figure(figsize=(6,6))
    plt.title('Validation ROC')
    plt.plot(fpr, tpr, 'b', label = 'Val AUC = %0.3f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
start_time = time.time()
all_metrics_pred = dbscan_(label_data[list(all_metrics)])   
result(label_data.label, all_metrics_pred, "All metrics")        
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
selected_features_pred = dbscan_(label_data[list(selected_features.index)]) 
result(label_data.label, selected_features_pred, "Correlation selected metrics")   
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
selected_features_pred = dbscan_(pca_df)       
result(label_data.label, selected_features_pred, "PCA selected metrics")   
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# All metrics
# Accuracy:  0.7468619246861925
# Precision:  0.6378504672897196
# Recall:  0.568291779521726
# F1 score:  0.5691287667150892
# --- 0.37237000465393066 seconds ---
# Correlation selected metrics
# Accuracy:  0.7928870292887029
# Precision:  0.7278846153846155
# Recall:  0.6810542398777693
# F1 score:  0.6968928344958782
# --- 0.4103429317474365 seconds ---
# PCA selected metrics
# Accuracy:  0.7656903765690377
# Precision:  0.6861223770058191
# Recall:  0.6710419705072111
# F1 score:  0.6774628879892037
# --- 0.40495800971984863 seconds ---

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans

    
def cluster(data):
    data = pd.DataFrame(data)
    clf = KMeans(n_clusters=2)
    clf.fit(data)
    
    # always classify anomaly as 1
    labels = clf.labels_
    one_counts = list(labels).count(1)
    zero_counts = list(labels).count(0)
    
#     if one_counts > zero_counts:
# #         print(labels)
#         labels = [not i for i in labels]
#         labels = map(int, labels)
#         print(labels)
    
    return labels

def plot_kmeans(df, predictions, column, plot=True):
    
#     predictions = pd.DataFrame(predictions, columns = ['predictions'])
    df_copy = df.copy()
    df_copy['predictions'] = predictions
    
    if not plot:
        return df_copy

    fig, ax = plt.subplots(figsize=(10,6))
    a = df.loc[df_copy['predictions'] == 1, ['time', column]] #anomaly
    b = df.loc[df_copy['label'] == 1, ['time',column]] #anomaly
    ax.plot(df_copy['time'], df_copy[column], color='blue')

    ax.scatter(b['time'],b[column], color='green', label='Measured anomaly')
    ax.scatter(a['time'],a[column], color='red', label='Predicted Anomaly')
    plt.xlabel('Date Time Integer')
    plt.ylabel(column)

    plt.legend()
    plt.show()
    return df_copy
    
def evaluate(df):
    # Evaluation
    
    # accuracy
    true_label = df['label']
    pred_label = df['predictions']
    accuracy = accuracy_score(true_label,pred_label)
    print('Accuracy: ', accuracy)
    # precision
    precision = precision_score(true_label, pred_label, average='macro')
    print('Precision: ', precision)
    # recall
    recall = metrics.recall_score(true_label, pred_label, average='macro')
    print('Recall: ', recall)
    f1_score = metrics.f1_score(true_label, pred_label, average='macro') 
    print('F1 score: ', f1_score)

    # AUC curve
    fpr, tpr, threshold = metrics.roc_curve(true_label, pred_label)
    roc_auc = metrics.auc(fpr, tpr)
    plt.figure(figsize=(6,6))
    plt.title('Validation ROC')
    plt.plot(fpr, tpr, 'b', label = 'Val AUC = %0.3f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()

# %%
start_time=time.time()
clf = KMeans(n_clusters=2)
clf.fit(label_data.drop(["label", "time"], axis=1))
result(label_data.label, clf.labels_, "kmeans on all metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time=time.time()
clf = KMeans(n_clusters=2)
clf.fit(label_data[list(selected_features_names)])
result(label_data.label, clf.labels_, "kmeans on correlation metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time=time.time()
clf = KMeans(n_clusters=2)
clf.fit(pca_df)
result(label_data.label, clf.labels_, "kmeans op PCA")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# kmeans on all metrics
# Accuracy:  0.608786610878661
# Precision:  0.6964285714285714
# Recall:  0.7380952380952381
# F1 score:  0.6046319272125724
# --- 0.1729750633239746 seconds ---
# kmeans on correlation metrics
# Accuracy:  0.9225941422594143
# Precision:  0.9482676791646891
# Recall:  0.849839109197398
# F1 score:  0.8859284198577169
# --- 0.17178106307983398 seconds ---
# kmeans op PCA
# Accuracy:  0.3912133891213389
# Precision:  0.30357142857142855
# Recall:  0.2619047619047619
# F1 score:  0.28120300751879695
# --- 0.15903306007385254 seconds ---

# %% [markdown]
# # SUPERVISED METHODS
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier,RadiusNeighborsClassifier

start_time = time.time()
model = KNeighborsClassifier(n_neighbors=2)
model.fit(X_train, Y_train)
predictions = model.predict(X_test)
result(Y_test, predictions, "Knn on all metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
model = KNeighborsClassifier(n_neighbors=2)
model.fit(X_train[list(selected_features_names)], Y_train)
predictions = model.predict(X_test[list(selected_features_names)])
result(Y_test, predictions, "Knn on correlation metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
model = KNeighborsClassifier(n_neighbors=2)
model.fit(X_pca_train, Y_pca_train)
predictions = model.predict(X_pca_test)
result(Y_pca_test, predictions, "Knn on pcs data")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Knn on all metrics
# Accuracy:  0.9895833333333334
# Precision:  0.9935064935064934
# Recall:  0.975
# F1 score:  0.9839115133232781
# --- 0.14459586143493652 seconds ---
# Knn on correlation metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.14209389686584473 seconds ---
# Knn on pcs data
# Accuracy:  0.9895833333333334
# Precision:  0.9935064935064934
# Recall:  0.975
# F1 score:  0.9839115133232781
# --- 0.1388716697692871 seconds ---

# %% [markdown]
# # SVM

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_train, Y_train)
pred = clf.predict(X_test)
result(Y_test, pred, "SVM on all metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_train[selected_features_names], Y_train)
pred = clf.predict(X_test[selected_features_names])
result(Y_test, pred, "SVM on correlation metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_pca_train, Y_pca_train)
pred = clf.predict(X_pca_test)
result(Y_pca_test, pred, "SVM on PCA metrics")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# SVM on all metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.14510631561279297 seconds ---
# SVM on correlation metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.14241814613342285 seconds ---
# SVM on PCA metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.16349577903747559 seconds ---

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

clf = RandomForestClassifier(max_depth=2, random_state=0)

start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_train, Y_train)
pred = clf.predict(X_test)
result(Y_test, pred, "SVM on all metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_train[selected_features_names], Y_train)
pred = clf.predict(X_test[selected_features_names])
result(Y_test, pred, "SVM on correlation metrics")
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X_pca_train, Y_pca_train)
pred = clf.predict(X_pca_test)
result(Y_pca_test, pred, "SVM on PCA metrics")
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# SVM on all metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.14348196983337402 seconds ---
# SVM on correlation metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.1408088207244873 seconds ---
# SVM on PCA metrics
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 score:  1.0
# --- 0.13232898712158203 seconds ---
